# %% [markdown]
# ### Using Google Colab
#
# This notebook has the pip command for installing MONAI and will be added to any subsequent notebook.
#
# **Required Packages for Colab Execution**
#
# Execute the following cell to install MONAI the first time a colab notebook is run:

# %%
# !pip install -qU "monai[ignite, nibabel, torchvision, tqdm]==0.5.0"

# %% [markdown]
# **Enabling GPU Support**
#
# To use GPU resources through Colab, change the runtime to GPU:
#
# 1. From the **"Runtime"** menu select **"Change Runtime Type"**
# 2. Choose **"GPU"** from the drop-down menu
# 3. Click **"SAVE"**
#
# This will reset the notebook and probably ask you if you are a robot (these instructions assume you are not). Running
#
# **!nvidia-smi**
#
# in a cell will verify this has worked and show you what kind of hardware you have access to.

# %%
# !nvidia-smi

# %% [markdown]
# # End-to-end Training with Pytorch and Ignite
# ---

# %% [markdown]
# We've covered a lot of material and now it's time to apply the things that we've learned in an end-to-end example.  First, we're going to use the basic PyTorch paradigm for training our model.  We'll then look at how to train using the Ignite workflows to make things even easier!
#
#
# ## End-to-End Training Workflow
#
# To help guide you through training your first model using MONAI, this guide will will cover six key phases:
#
# 1. **Setting up our Dataset and exploring the data**
# 2. **Preparing datasets and transforms**
# 3. **Define your network and create our PyTorch training loop**
# 4. **Evaluate your model and understand the results**
# 5. **Start using Ignite and more about determinism**

# %% [markdown]
# Let's get started by importing our dependencies.

# %%
import os
import shutil
import tempfile

import matplotlib.pyplot as plt
import numpy as np
import PIL

import torch
import monai

from monai.apps import download_and_extract
from monai.config import print_config
from monai.metrics import compute_roc_auc
from monai.networks.nets import DenseNet121
from monai.transforms import (
    AddChannel,
    Compose,
    LoadImage,
    RandFlip,
    RandRotate,
    RandZoom,
    ScaleIntensity,
    ToTensor,
    Activations,
    AsDiscrete
)
from monai.utils import set_determinism

# %% [markdown]
# ## **1. Setting up our Dataset and exploring the data**

# %% [markdown]
# #### Setup data directory
#
# We'll create a temporary directory for all the MONAI data we're going to be using called MONAI_DATA_DIRECTORY.

# %%
directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /tmp/tmpxyemt58e

# %% [markdown]
# #### Download the MedNIST dataset
# The `MedNIST` dataset was gathered from several sets from [TCIA](https://wiki.cancerimagingarchive.net/display/Public/Data+Usage+Policies+and+Restrictions),
# [the RSNA Bone Age Challenge](http://rsnachallenges.cloudapp.net/competitions/4),
# and [the NIH Chest X-ray dataset](https://cloud.google.com/healthcare/docs/resources/public-datasets/nih-chest).
#
# The dataset is kindly made available by [Dr. Bradley J. Erickson M.D., Ph.D.](https://www.mayo.edu/research/labs/radiology-informatics/overview) (Department of Radiology, Mayo Clinic)
# under the Creative Commons [CC BY-SA 4.0 license](https://creativecommons.org/licenses/by-sa/4.0/). If you use the MedNIST dataset, please acknowledge the source.
#
# We're going to download this dataset below and extract it into our temporary MONAI Data Directory.

# %%
resource = "https://www.dropbox.com/s/5wwskxctvcxiuea/MedNIST.tar.gz?dl=1"
md5 = "0bc7306e7427e00ad1c5526a6677552d"

compressed_file = os.path.join(root_dir, "MedNIST.tar.gz")
data_dir = os.path.join(root_dir, "MedNIST")
if not os.path.exists(data_dir):
    download_and_extract(resource, compressed_file, root_dir, md5)
# Out:
# MedNIST.tar.gz: 59.0MB [00:01, 34.3MB/s]
# downloaded file: /tmp/tmpxyemt58e/MedNIST.tar.gz.
# Verified 'MedNIST.tar.gz', md5: 0bc7306e7427e00ad1c5526a6677552d.
# Verified 'MedNIST.tar.gz', md5: 0bc7306e7427e00ad1c5526a6677552d.

# %% [markdown]
# #### Set deterministic training for reproducibility
# [set_determinism](https://docs.monai.io/en/latest/utils.html?highlight=set_determinism#monai.utils.misc.set_determinism) will set the random seeds in both Numpy and PyTorch to ensure reproducibility. We'll see later that we need to go a little bit further to ensure reproducibility in a jupyter notebook

# %%
set_determinism(seed=0)

# %% [markdown]
# #### Read the image filenames from the dataset folders
#
# When using a dataset, you want to understand the basics of the images, labels, and more.  We'll start off by showing some of those basic statistics for MedNIST.
#
# We'll see that 6 different folders are representing 6 different categories: Hand, AbdomenCT, CXR, ChestCT, BreastMRI, HeadCT.  We'll be using each of these categories as our label names.

# %%
class_names = sorted(x for x in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, x)))
num_class = len(class_names)
image_files = [
    [
        os.path.join(data_dir, class_names[i], x)
        for x in os.listdir(os.path.join(data_dir, class_names[i]))
    ]
    for i in range(num_class)
]
num_each = [len(image_files[i]) for i in range(num_class)]
image_files_list = []
image_class = []
for i in range(num_class):
    image_files_list.extend(image_files[i])
    image_class.extend([i] * num_each[i])
num_total = len(image_class)
image_width, image_height = PIL.Image.open(image_files_list[0]).size

print(f"Total image count: {num_total}")
print(f"Image dimensions: {image_width} x {image_height}")
print(f"Label names: {class_names}")
print(f"Label counts: {num_each}")
# Out:
# Total image count: 58954
# Image dimensions: 64 x 64
# Label names: ['AbdomenCT', 'BreastMRI', 'CXR', 'ChestCT', 'Hand', 'HeadCT']
# Label counts: [10000, 8954, 10000, 10000, 10000, 10000]

# %% [markdown]
# #### Randomly pick images from the dataset to visualize and check
#
# We want to understand what the images we're using look like, so we'll start by visualizing a few random images.

# %%
plt.subplots(3, 3, figsize=(8, 8))
for i, k in enumerate(np.random.randint(num_total, size=9)):
    im = PIL.Image.open(image_files_list[k])
    arr = np.array(im)
    plt.subplot(3, 3, i + 1)
    plt.xlabel(class_names[image_class[k]])
    plt.imshow(arr, cmap="gray", vmin=0, vmax=255)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **2. Preparing datasets and transforms**

# %% [markdown]
# #### Prepare training, validation, and test data lists
#
# We want to split the data into 3 different sets, one for training, one for validation, and one for testing.  We'll use a ratio of 80/10/10 for those sets.

# %%
val_frac = 0.1
test_frac = 0.1
train_x = list()
train_y = list()
val_x = list()
val_y = list()
test_x = list()
test_y = list()

for i in range(num_total):
    rann = np.random.random()
    if rann < val_frac:
        val_x.append(image_files_list[i])
        val_y.append(image_class[i])
    elif rann < test_frac + val_frac:
        test_x.append(image_files_list[i])
        test_y.append(image_class[i])
    else:
        train_x.append(image_files_list[i])
        train_y.append(image_class[i])

print(f"Training count: {len(train_x)}, Validation count: {len(val_x)}, Test count: {len(test_x)}")
# Out:
# Training count: 47156, Validation count: 5913, Test count: 5885

# %% [markdown]
# #### Define MONAI transforms, Dataset and Dataloader to pre-process data
#
# We'll define our transform using `Compose`.  In this Array of Transforms, we'll load the image, add a channel, scale its intensity, utilize a few random functions and finally create a tensor.

# %%
train_transforms = Compose(
    [
        LoadImage(image_only=True),
        AddChannel(),
        ScaleIntensity(),
        RandRotate(range_x=15, prob=0.5, keep_size=True),
        RandFlip(spatial_axis=0, prob=0.5),
        RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.5),
        ToTensor(),
    ]
)

val_transforms = Compose([LoadImage(image_only=True), AddChannel(), ScaleIntensity(), ToTensor()])

act = Activations(softmax=True)
to_onehot = AsDiscrete(to_onehot=True, n_classes=num_class)

# %% [markdown]
# #### Initialise the datasets and loaders for training, validation and test sets
#  * Define a simple dataset, that we'll call `MedNISTDataset`, that groups:
#    * Images
#    * Labels
#    * The transforms that are to be run on the images and labels
#  * Create three instances of this dataset:
#    * One for training
#    * One for validation
#    * One for testing
#
# We'll use a batch size of 512 and employ 10 workers to load the data.

# %%
batch_size = 512
num_workers = 10

class MedNISTDataset(torch.utils.data.Dataset):
    def __init__(self, image_files, labels, transforms):
        self.image_files = image_files
        self.labels = labels
        self.transforms = transforms

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, index):
        return self.transforms(self.image_files[index]), self.labels[index]


train_ds = MedNISTDataset(train_x, train_y, train_transforms)
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers)

val_ds = MedNISTDataset(val_x, val_y, val_transforms)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=batch_size, num_workers=num_workers)

test_ds = MedNISTDataset(test_x, test_y, val_transforms)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, num_workers=num_workers)

# %% [markdown]
# ## **3. Define your network and create our PyTorch training loop**

# %% [markdown]
# #### Define network and optimizer
#
# 1. Set `learning_rate` for how much the model is updated per step
# 1. The fetch a pytorch `device` for the GPU
# 1. Instantiate a [densenet121](https://docs.monai.io/en/latest/networks.html?highlight=densenet#monai.networks.nets.densenet121) model instance and 'send' it to the GPU using `device`
#   * This is a standard MONAI implementation; it is capable of 2D and 3D operation but here we are using it in 2D mode
# 1. We'll make use of the Adam optimizer

# %%
learning_rate = 1e-5
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = DenseNet121(spatial_dims=2, in_channels=1, out_channels=num_class).to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), learning_rate)

# %% [markdown]
# #### Network training
# We are hand-rolling a basic pytorch training loop here:
#  * standard pytorch training loop
#    * step through each training epoch, running through the training set in batches
#    * after each epoch, run a validation pass, evaluating the network
#    * if it shows improved performance, save out the model weights
#  * later we will revisit training loops in a more Ignite / MONAI fashion

# %%
epoch_num = 4
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()

for epoch in range(epoch_num):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{epoch_num}")

    epoch_loss = 0
    step = 1

    steps_per_epoch = len(train_ds) // train_loader.batch_size

    # put the network in train mode; this tells the network and its modules to
    # enable training elements such as normalisation and dropout, where applicable
    net.train()
    for batch_data in train_loader:

        # move the data to the GPU
        inputs, labels = batch_data[0].to(device), batch_data[1].to(device)

        # prepare the gradients for this step's back propagation
        optimizer.zero_grad()
        
        # run the network forwards
        outputs = net(inputs)
        
        # run the loss function on the outputs
        loss = loss_function(outputs, labels)
        
        # compute the gradients
        loss.backward()
        
        # tell the optimizer to update the weights according to the gradients
        # and its internal optimisation strategy
        optimizer.step()

        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size + 1}, training_loss: {loss.item():.4f}")
        step += 1

    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    # after each epoch, run our metrics to evaluate it, and, if they are an improvement,
    # save the model out
    
    # switch off training features of the network for this pass
    net.eval()

    # 'with torch.no_grad()' switches off gradient calculation for the scope of its context
    with torch.no_grad():
        # create lists to which we will concatenate the the validation results
        images = list()
        labels = list()

        # iterate over each batch of images and run them through the network in evaluation mode
        for val_data in val_loader:
            val_images, val_labels = val_data[0].to(device), val_data[1].to(device)

            # run the network
            val_pred = net(val_images)

            images.append(val_pred)
            labels.append(val_labels)

        # concatenate the predicted labels with each other and the actual labels with each other
        y_pred = torch.cat(images)
        y = torch.cat(labels)

        # we are using the area under the receiver operating characteristic (ROC) curve to determine
        # whether this epoch has improved the best performance of the network so far, in which case
        # we save the network in this state
        y_onehot = to_onehot(y)
        y_pred_act = act(y_pred)        
        auc_metric = compute_roc_auc(y_pred_act, y_onehot)
        del y_pred_act, y_onehot
        metric_values.append(auc_metric)
        acc_value = torch.eq(y_pred.argmax(dim=1), y)
        acc_metric = acc_value.sum().item() / len(acc_value)
        if auc_metric > best_metric:
            best_metric = auc_metric
            best_metric_epoch = epoch + 1
            torch.save(net.state_dict(), os.path.join(root_dir, "best_metric_model.pth"))
            print("saved new best metric network")
        print(
            f"current epoch: {epoch + 1} current AUC: {auc_metric:.4f} /"
            f" current accuracy: {acc_metric:.4f} best AUC: {best_metric:.4f} /"
            f" at epoch: {best_metric_epoch}"
        )

print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")

# %% [markdown]
# #### Plot the loss and metric
#
# Once we're done training we want to visualize our Loss and Accuracy.

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val AUC")
x = [(i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## **4. Evaluate your model and understand the results**

# %% [markdown]
# #### Evaluate the model on the test dataset
#
# After training and validation, we now have the best model as determined by the validation dataset.  But now we need to evaluate the model on the test dataset to check whether the final model is robust and not over-fitting.  We'll use these predictions to generate a classification report.

# %%
net.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
net.eval()
y_true = list()
y_pred = list()
with torch.no_grad():
    for test_data in test_loader:
        test_images, test_labels = (
            test_data[0].to(device),
            test_data[1].to(device),
        )
        pred = net(test_images).argmax(dim=1)
        for i in range(len(pred)):
            y_true.append(test_labels[i].item())
            y_pred.append(pred[i].item())

# %% [markdown]
# #### Some light analytics - classification report
#
# We'll utilize scikit-learn's classification report to get the precision, recall, and f1-score for each category.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# %% [markdown]
# #### Some light analytics - confusion matrix
#
# Let's also create a confusion matrix to get a better understanding of the failure cases

# %%
from sklearn.metrics import confusion_matrix
cmat = confusion_matrix(y_true, y_pred)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion_matrix(y_true, y_pred), cmap="terrain", interpolation='nearest')
fig.colorbar(cax)

ax.set_xticklabels(['']+class_names, rotation=270)
ax.set_yticklabels(['']+class_names)

plt.show()

# %% [markdown]
# ## **5. Start using Ignite and more about determinism**

# %% [markdown]
# #### Let's make some changes
# Everything that we have done so far uses MONAI with pytorch in a very vanilla fashion. The initial training / validation loop is written to show you the nuts and bolts of pytorch. Now let's explore starting the move towards [ignite](https://pytorch.org/ignite/) and features of MONAI designed to work with it.
#
# <img src="workflows.png" style="width: 700px;"/>

# %%
from ignite.engine import Events, create_supervised_evaluator, create_supervised_trainer
from ignite.handlers import ModelCheckpoint
from ignite.metrics import Accuracy
from monai.handlers import ROCAUC

step = 1
iter_losses=[]
batch_sizes=[]
epoch_loss_values = []
metric_values = []

iter_losses=[]
epoch_loss_values = []
metric_values = []

# Training

# this trainer takes care of the training loop for us
trainer = create_supervised_trainer(net, optimizer, loss_function, device, False)

# calculate the number of steps per epoch up front
steps_per_epoch = len(train_ds) // train_loader.batch_size
if len(train_ds) % train_loader.batch_size != 0:
    steps_per_epoch += 1


# create a handler for recording the loss after each input. Improve upon our earlier example
# by also recording the batch size, so we can perform a weighted average for the overall average
# loss
@trainer.on(Events.ITERATION_COMPLETED)
def _end_iter(engine):
    global step
    loss = engine.state.output
    batch_len = len(engine.state.batch[0])
    epoch = engine.state.epoch
    epoch_len = engine.state.max_epochs
    iter_losses.append(loss)
    batch_sizes.append(batch_len)
    print(f'epoch {epoch}/{epoch_len}, step {step}/{steps_per_epoch}, training_loss = {loss:.4f}')    
    step += 1
    
# Validation

val_metrics = {'accuracy': Accuracy(), 'rocauc': ROCAUC(output_transform=lambda x: (act(x[0]), to_onehot(x[1])))}
evaluator = create_supervised_evaluator(net, val_metrics, device, True)

# validation is run every n training epochs in response to the trainer completing
# an epoch. Here we use the decorator syntax to add a function that runs it to the
# EPOCH_COMPLETED event
@trainer.on(Events.EPOCH_COMPLETED)
def run_validation(engine):
    global step
    evaluator.run(val_loader)

    # the overall average loss must be weighted by batch size
    overall_average_loss = np.average(iter_losses, weights=batch_sizes)
    epoch_loss_values.append(overall_average_loss)

    # clear the contents of iter_losses and batch_sizes for the next epoch
    del iter_losses[:]
    del batch_sizes[:]
    
    # fetch and report the validation metrics
    acc = evaluator.state.metrics['accuracy']
    roc = evaluator.state.metrics['rocauc']
    metric_values.append(roc)
    print(f"evaluation for epoch {engine.state.epoch}, accuracy = {acc:.4f}, rocauc = {roc:.4f}")

    # reset step for the next epoch
    step = 1
    
# create a checkpoint handler to save the network weights based on the area under the ROC curve
# as before
def _score(_):
    return metric_values[-1]

# create a model checkpointer to save the network
checkpoint_handler = ModelCheckpoint(root_dir, filename_prefix='best_metric_model', score_name='',
                                     n_saved=1, require_empty=False, score_function=_score)

# handlers are attached to events in trainers and evaluators
trainer.add_event_handler(event_name=Events.EPOCH_COMPLETED,
                          handler=checkpoint_handler, to_save={'net': net})
# train (and evaluate) the network, Ignite-style!
train_epochs = 4
state = trainer.run(train_loader, train_epochs)

best_rocauc = max(metric_values)
print(f"train completed, best_metric: {best_rocauc:.4f} at epoch: {metric_values.index(best_rocauc)}")
# Out:
# epoch 1/4, step 1/93, training_loss = 1.7799
# epoch 1/4, step 2/93, training_loss = 1.7520
# epoch 1/4, step 3/93, training_loss = 1.7363
# epoch 1/4, step 4/93, training_loss = 1.7106
# epoch 1/4, step 5/93, training_loss = 1.6840
# epoch 1/4, step 6/93, training_loss = 1.6632
# epoch 1/4, step 7/93, training_loss = 1.6251
# epoch 1/4, step 8/93, training_loss = 1.6184
# epoch 1/4, step 9/93, training_loss = 1.6003
# epoch 1/4, step 10/93, training_loss = 1.5770
# epoch 1/4, step 11/93, training_loss = 1.5458
# epoch 1/4, step 12/93, training_loss = 1.5253
# epoch 1/4, step 13/93, training_loss = 1.4906
# epoch 1/4, step 14/93, training_loss = 1.4697
# epoch 1/4, step 15/93, training_loss = 1.4789
# epoch 1/4, step 16/93, training_loss = 1.4567
# epoch 1/4, step 17/93, training_loss = 1.4315
# epoch 1/4, step 18/93, training_loss = 1.4239
# epoch 1/4, step 19/93, training_loss = 1.4031
# epoch 1/4, step 20/93, training_loss = 1.3688
# epoch 1/4, step 21/93, training_loss = 1.3616
# epoch 1/4, step 22/93, training_loss = 1.3593
# epoch 1/4, step 23/93, training_loss = 1.3551
# epoch 1/4, step 24/93, training_loss = 1.3181
# epoch 1/4, step 25/93, training_loss = 1.2852
# epoch 1/4, step 26/93, training_loss = 1.2712
# epoch 1/4, step 27/93, training_loss = 1.2646
# epoch 1/4, step 28/93, training_loss = 1.2495
# epoch 1/4, step 29/93, training_loss = 1.2255
# epoch 1/4, step 30/93, training_loss = 1.2432
# epoch 1/4, step 31/93, training_loss = 1.2458
# epoch 1/4, step 32/93, training_loss = 1.1757
# epoch 1/4, step 33/93, training_loss = 1.1513
# epoch 1/4, step 34/93, training_loss = 1.1809
# epoch 1/4, step 35/93, training_loss = 1.1598
# epoch 1/4, step 36/93, training_loss = 1.1282
# epoch 1/4, step 37/93, training_loss = 1.1329
# epoch 1/4, step 38/93, training_loss = 1.0981
# epoch 1/4, step 39/93, training_loss = 1.0812
# epoch 1/4, step 40/93, training_loss = 1.0478
# epoch 1/4, step 41/93, training_loss = 1.0505
# epoch 1/4, step 42/93, training_loss = 1.0485
# epoch 1/4, step 43/93, training_loss = 1.0385
# epoch 1/4, step 44/93, training_loss = 1.0256
# epoch 1/4, step 45/93, training_loss = 0.9869
# epoch 1/4, step 46/93, training_loss = 0.9927
# epoch 1/4, step 47/93, training_loss = 0.9863
# epoch 1/4, step 48/93, training_loss = 0.9837
# epoch 1/4, step 49/93, training_loss = 0.9542
# epoch 1/4, step 50/93, training_loss = 0.9459
# epoch 1/4, step 51/93, training_loss = 0.9585
# epoch 1/4, step 52/93, training_loss = 0.8875
# epoch 1/4, step 53/93, training_loss = 0.9194
# epoch 1/4, step 54/93, training_loss = 0.9283
# epoch 1/4, step 55/93, training_loss = 0.9183
# epoch 1/4, step 56/93, training_loss = 0.9067
# epoch 1/4, step 57/93, training_loss = 0.8745
# epoch 1/4, step 58/93, training_loss = 0.8618
# epoch 1/4, step 59/93, training_loss = 0.8400
# epoch 1/4, step 60/93, training_loss = 0.8316
# epoch 1/4, step 61/93, training_loss = 0.8598
# epoch 1/4, step 62/93, training_loss = 0.8608
# epoch 1/4, step 63/93, training_loss = 0.8187
# epoch 1/4, step 64/93, training_loss = 0.8261
# epoch 1/4, step 65/93, training_loss = 0.7846
# epoch 1/4, step 66/93, training_loss = 0.7932
# epoch 1/4, step 67/93, training_loss = 0.7699
# epoch 1/4, step 68/93, training_loss = 0.7998
# epoch 1/4, step 69/93, training_loss = 0.7603
# epoch 1/4, step 70/93, training_loss = 0.7478
# epoch 1/4, step 71/93, training_loss = 0.7393
# epoch 1/4, step 72/93, training_loss = 0.7106
# epoch 1/4, step 73/93, training_loss = 0.7310
# epoch 1/4, step 74/93, training_loss = 0.7147
# epoch 1/4, step 75/93, training_loss = 0.6932
# epoch 1/4, step 76/93, training_loss = 0.6852
# epoch 1/4, step 77/93, training_loss = 0.7029
# epoch 1/4, step 78/93, training_loss = 0.6752
# epoch 1/4, step 79/93, training_loss = 0.6643
# epoch 1/4, step 80/93, training_loss = 0.6601
# epoch 1/4, step 81/93, training_loss = 0.6797
# epoch 1/4, step 82/93, training_loss = 0.6506
# epoch 1/4, step 83/93, training_loss = 0.6254
# epoch 1/4, step 84/93, training_loss = 0.6495
# epoch 1/4, step 85/93, training_loss = 0.6089
# epoch 1/4, step 86/93, training_loss = 0.6368
# epoch 1/4, step 87/93, training_loss = 0.6312
# epoch 1/4, step 88/93, training_loss = 0.6193
# epoch 1/4, step 89/93, training_loss = 0.5657
# epoch 1/4, step 90/93, training_loss = 0.5794
# epoch 1/4, step 91/93, training_loss = 0.6150
# epoch 1/4, step 92/93, training_loss = 0.5638
# epoch 1/4, step 93/93, training_loss = 0.4762
# evaluation for epoch 1, accuracy = 0.9364, rocauc = 0.9930
# epoch 2/4, step 1/93, training_loss = 0.5870
# epoch 2/4, step 2/93, training_loss = 0.5567
# epoch 2/4, step 3/93, training_loss = 0.5586
# epoch 2/4, step 4/93, training_loss = 0.5511
# epoch 2/4, step 5/93, training_loss = 0.5893
# epoch 2/4, step 6/93, training_loss = 0.5453
# epoch 2/4, step 7/93, training_loss = 0.5715
# epoch 2/4, step 8/93, training_loss = 0.5101
# epoch 2/4, step 9/93, training_loss = 0.5301
# epoch 2/4, step 10/93, training_loss = 0.4897
# epoch 2/4, step 11/93, training_loss = 0.5178
# epoch 2/4, step 12/93, training_loss = 0.4959
# epoch 2/4, step 13/93, training_loss = 0.4847
# epoch 2/4, step 14/93, training_loss = 0.5070
# epoch 2/4, step 15/93, training_loss = 0.4743
# epoch 2/4, step 16/93, training_loss = 0.4528
# epoch 2/4, step 17/93, training_loss = 0.4735
# epoch 2/4, step 18/93, training_loss = 0.4610
# epoch 2/4, step 19/93, training_loss = 0.4223
# epoch 2/4, step 20/93, training_loss = 0.4369
# epoch 2/4, step 21/93, training_loss = 0.4696
# epoch 2/4, step 22/93, training_loss = 0.4444
# epoch 2/4, step 23/93, training_loss = 0.4668
# epoch 2/4, step 24/93, training_loss = 0.4416
# epoch 2/4, step 25/93, training_loss = 0.4135
# epoch 2/4, step 26/93, training_loss = 0.4323
# epoch 2/4, step 27/93, training_loss = 0.4269
# epoch 2/4, step 28/93, training_loss = 0.4211
# epoch 2/4, step 29/93, training_loss = 0.4202
# epoch 2/4, step 30/93, training_loss = 0.4130
# epoch 2/4, step 31/93, training_loss = 0.3989
# epoch 2/4, step 32/93, training_loss = 0.4069
# epoch 2/4, step 33/93, training_loss = 0.3844
# epoch 2/4, step 34/93, training_loss = 0.4197
# epoch 2/4, step 35/93, training_loss = 0.3917
# epoch 2/4, step 36/93, training_loss = 0.3895
# epoch 2/4, step 37/93, training_loss = 0.3804
# epoch 2/4, step 38/93, training_loss = 0.3387
# epoch 2/4, step 39/93, training_loss = 0.3416
# epoch 2/4, step 40/93, training_loss = 0.3777
# epoch 2/4, step 41/93, training_loss = 0.3543
# epoch 2/4, step 42/93, training_loss = 0.3766
# epoch 2/4, step 43/93, training_loss = 0.3432
# epoch 2/4, step 44/93, training_loss = 0.3696
# epoch 2/4, step 45/93, training_loss = 0.3369
# epoch 2/4, step 46/93, training_loss = 0.3359
# epoch 2/4, step 47/93, training_loss = 0.3679
# epoch 2/4, step 48/93, training_loss = 0.3345
# epoch 2/4, step 49/93, training_loss = 0.3248
# epoch 2/4, step 50/93, training_loss = 0.3408
# epoch 2/4, step 51/93, training_loss = 0.3453
# epoch 2/4, step 52/93, training_loss = 0.3271
# epoch 2/4, step 53/93, training_loss = 0.3253
# epoch 2/4, step 54/93, training_loss = 0.3419
# epoch 2/4, step 55/93, training_loss = 0.2977
# epoch 2/4, step 56/93, training_loss = 0.3359
# epoch 2/4, step 57/93, training_loss = 0.3176
# epoch 2/4, step 58/93, training_loss = 0.3008
# epoch 2/4, step 59/93, training_loss = 0.3002
# epoch 2/4, step 60/93, training_loss = 0.2960
# epoch 2/4, step 61/93, training_loss = 0.3102
# epoch 2/4, step 62/93, training_loss = 0.3127
# epoch 2/4, step 63/93, training_loss = 0.3113
# epoch 2/4, step 64/93, training_loss = 0.3049
# epoch 2/4, step 65/93, training_loss = 0.2801
# epoch 2/4, step 66/93, training_loss = 0.2969
# epoch 2/4, step 67/93, training_loss = 0.2874
# epoch 2/4, step 68/93, training_loss = 0.3208
# epoch 2/4, step 69/93, training_loss = 0.2749
# epoch 2/4, step 70/93, training_loss = 0.2711
# epoch 2/4, step 71/93, training_loss = 0.2739
# epoch 2/4, step 72/93, training_loss = 0.2711
# epoch 2/4, step 73/93, training_loss = 0.2972
# epoch 2/4, step 74/93, training_loss = 0.2577
# epoch 2/4, step 75/93, training_loss = 0.2731
# epoch 2/4, step 76/93, training_loss = 0.2589
# epoch 2/4, step 77/93, training_loss = 0.2555
# epoch 2/4, step 78/93, training_loss = 0.2775
# epoch 2/4, step 79/93, training_loss = 0.2875
# epoch 2/4, step 80/93, training_loss = 0.2573
# epoch 2/4, step 81/93, training_loss = 0.2554
# epoch 2/4, step 82/93, training_loss = 0.2540
# epoch 2/4, step 83/93, training_loss = 0.2457
# epoch 2/4, step 84/93, training_loss = 0.2527
# epoch 2/4, step 85/93, training_loss = 0.2182
# epoch 2/4, step 86/93, training_loss = 0.2492
# epoch 2/4, step 87/93, training_loss = 0.2544
# epoch 2/4, step 88/93, training_loss = 0.2593
# epoch 2/4, step 89/93, training_loss = 0.2518
# epoch 2/4, step 90/93, training_loss = 0.2516
# epoch 2/4, step 91/93, training_loss = 0.2167
# epoch 2/4, step 92/93, training_loss = 0.2392
# epoch 2/4, step 93/93, training_loss = 0.2084
# evaluation for epoch 2, accuracy = 0.9669, rocauc = 0.9987
# epoch 3/4, step 1/93, training_loss = 0.2231
# epoch 3/4, step 2/93, training_loss = 0.2387
# epoch 3/4, step 3/93, training_loss = 0.2147
# epoch 3/4, step 4/93, training_loss = 0.2527
# epoch 3/4, step 5/93, training_loss = 0.2034
# epoch 3/4, step 6/93, training_loss = 0.2356
# epoch 3/4, step 7/93, training_loss = 0.2100
# epoch 3/4, step 8/93, training_loss = 0.2224
# epoch 3/4, step 9/93, training_loss = 0.2428
# epoch 3/4, step 10/93, training_loss = 0.2407
# epoch 3/4, step 11/93, training_loss = 0.2262
# epoch 3/4, step 12/93, training_loss = 0.2238
# epoch 3/4, step 13/93, training_loss = 0.2073
# epoch 3/4, step 14/93, training_loss = 0.2169
# epoch 3/4, step 15/93, training_loss = 0.2318
# epoch 3/4, step 16/93, training_loss = 0.2151
# epoch 3/4, step 17/93, training_loss = 0.1857
# epoch 3/4, step 18/93, training_loss = 0.1942
# epoch 3/4, step 19/93, training_loss = 0.1902
# epoch 3/4, step 20/93, training_loss = 0.1901
# epoch 3/4, step 21/93, training_loss = 0.1912
# epoch 3/4, step 22/93, training_loss = 0.1782
# epoch 3/4, step 23/93, training_loss = 0.1981
# epoch 3/4, step 24/93, training_loss = 0.2081
# epoch 3/4, step 25/93, training_loss = 0.1765
# epoch 3/4, step 26/93, training_loss = 0.1905
# epoch 3/4, step 27/93, training_loss = 0.1741
# epoch 3/4, step 28/93, training_loss = 0.1828
# epoch 3/4, step 29/93, training_loss = 0.1863
# epoch 3/4, step 30/93, training_loss = 0.1775
# epoch 3/4, step 31/93, training_loss = 0.1792
# epoch 3/4, step 32/93, training_loss = 0.1793
# epoch 3/4, step 33/93, training_loss = 0.1916
# epoch 3/4, step 34/93, training_loss = 0.1974
# epoch 3/4, step 35/93, training_loss = 0.1555
# epoch 3/4, step 36/93, training_loss = 0.2028
# epoch 3/4, step 37/93, training_loss = 0.1688
# epoch 3/4, step 38/93, training_loss = 0.1560
# epoch 3/4, step 39/93, training_loss = 0.1779
# epoch 3/4, step 40/93, training_loss = 0.1564
# epoch 3/4, step 41/93, training_loss = 0.1645
# epoch 3/4, step 42/93, training_loss = 0.1640
# epoch 3/4, step 43/93, training_loss = 0.1534
# epoch 3/4, step 44/93, training_loss = 0.1994
# epoch 3/4, step 45/93, training_loss = 0.1678
# epoch 3/4, step 46/93, training_loss = 0.1594
# epoch 3/4, step 47/93, training_loss = 0.1592
# epoch 3/4, step 48/93, training_loss = 0.1888
# epoch 3/4, step 49/93, training_loss = 0.1586
# epoch 3/4, step 50/93, training_loss = 0.1637
# epoch 3/4, step 51/93, training_loss = 0.1647
# epoch 3/4, step 52/93, training_loss = 0.1647
# epoch 3/4, step 53/93, training_loss = 0.1770
# epoch 3/4, step 54/93, training_loss = 0.1816
# epoch 3/4, step 55/93, training_loss = 0.1671
# epoch 3/4, step 56/93, training_loss = 0.1615
# epoch 3/4, step 57/93, training_loss = 0.1638
# epoch 3/4, step 58/93, training_loss = 0.1850
# epoch 3/4, step 59/93, training_loss = 0.1533
# epoch 3/4, step 60/93, training_loss = 0.1481
# epoch 3/4, step 61/93, training_loss = 0.1407
# epoch 3/4, step 62/93, training_loss = 0.1656
# epoch 3/4, step 63/93, training_loss = 0.1742
# epoch 3/4, step 64/93, training_loss = 0.1728
# epoch 3/4, step 65/93, training_loss = 0.1460
# epoch 3/4, step 66/93, training_loss = 0.1412
# epoch 3/4, step 67/93, training_loss = 0.1653
# epoch 3/4, step 68/93, training_loss = 0.1561
# epoch 3/4, step 69/93, training_loss = 0.1362
# epoch 3/4, step 70/93, training_loss = 0.1503
# epoch 3/4, step 71/93, training_loss = 0.1676
# epoch 3/4, step 72/93, training_loss = 0.1561
# epoch 3/4, step 73/93, training_loss = 0.1354
# epoch 3/4, step 74/93, training_loss = 0.1321
# epoch 3/4, step 75/93, training_loss = 0.1233
# epoch 3/4, step 76/93, training_loss = 0.1364
# epoch 3/4, step 77/93, training_loss = 0.1251
# epoch 3/4, step 78/93, training_loss = 0.1414
# epoch 3/4, step 79/93, training_loss = 0.1361
# epoch 3/4, step 80/93, training_loss = 0.1226
# epoch 3/4, step 81/93, training_loss = 0.1351
# epoch 3/4, step 82/93, training_loss = 0.1322
# epoch 3/4, step 83/93, training_loss = 0.1220
# epoch 3/4, step 84/93, training_loss = 0.1396
# epoch 3/4, step 85/93, training_loss = 0.1536
# epoch 3/4, step 86/93, training_loss = 0.1079
# epoch 3/4, step 87/93, training_loss = 0.1120
# epoch 3/4, step 88/93, training_loss = 0.1357
# epoch 3/4, step 89/93, training_loss = 0.1260
# epoch 3/4, step 90/93, training_loss = 0.1236
# epoch 3/4, step 91/93, training_loss = 0.1251
# epoch 3/4, step 92/93, training_loss = 0.1333
# epoch 3/4, step 93/93, training_loss = 0.1641
# evaluation for epoch 3, accuracy = 0.9809, rocauc = 0.9994
# epoch 4/4, step 1/93, training_loss = 0.1331
# epoch 4/4, step 2/93, training_loss = 0.1034
# epoch 4/4, step 3/93, training_loss = 0.1147
# epoch 4/4, step 4/93, training_loss = 0.1184
# epoch 4/4, step 5/93, training_loss = 0.1585
# epoch 4/4, step 6/93, training_loss = 0.1278
# epoch 4/4, step 7/93, training_loss = 0.1347
# epoch 4/4, step 8/93, training_loss = 0.1155
# epoch 4/4, step 9/93, training_loss = 0.1202
# epoch 4/4, step 10/93, training_loss = 0.1393
# epoch 4/4, step 11/93, training_loss = 0.1334
# epoch 4/4, step 12/93, training_loss = 0.1116
# epoch 4/4, step 13/93, training_loss = 0.1164
# epoch 4/4, step 14/93, training_loss = 0.1047
# epoch 4/4, step 15/93, training_loss = 0.1149
# epoch 4/4, step 16/93, training_loss = 0.1251
# epoch 4/4, step 17/93, training_loss = 0.0927
# epoch 4/4, step 18/93, training_loss = 0.1268
# epoch 4/4, step 19/93, training_loss = 0.1240
# epoch 4/4, step 20/93, training_loss = 0.1121
# epoch 4/4, step 21/93, training_loss = 0.1447
# epoch 4/4, step 22/93, training_loss = 0.1134
# epoch 4/4, step 23/93, training_loss = 0.1181
# epoch 4/4, step 24/93, training_loss = 0.1121
# epoch 4/4, step 25/93, training_loss = 0.1033
# epoch 4/4, step 26/93, training_loss = 0.1074
# epoch 4/4, step 27/93, training_loss = 0.1300
# epoch 4/4, step 28/93, training_loss = 0.1000
# epoch 4/4, step 29/93, training_loss = 0.1033
# epoch 4/4, step 30/93, training_loss = 0.0977
# epoch 4/4, step 31/93, training_loss = 0.1326
# epoch 4/4, step 32/93, training_loss = 0.1348
# epoch 4/4, step 33/93, training_loss = 0.1019
# epoch 4/4, step 34/93, training_loss = 0.0959
# epoch 4/4, step 35/93, training_loss = 0.1140
# epoch 4/4, step 36/93, training_loss = 0.1159
# epoch 4/4, step 37/93, training_loss = 0.1210
# epoch 4/4, step 38/93, training_loss = 0.1085
# epoch 4/4, step 39/93, training_loss = 0.1104
# epoch 4/4, step 40/93, training_loss = 0.1046
# epoch 4/4, step 41/93, training_loss = 0.1002
# epoch 4/4, step 42/93, training_loss = 0.1215
# epoch 4/4, step 43/93, training_loss = 0.0917
# epoch 4/4, step 44/93, training_loss = 0.1157
# epoch 4/4, step 45/93, training_loss = 0.0906
# epoch 4/4, step 46/93, training_loss = 0.1007
# epoch 4/4, step 47/93, training_loss = 0.1022
# epoch 4/4, step 48/93, training_loss = 0.1078
# epoch 4/4, step 49/93, training_loss = 0.1018
# epoch 4/4, step 50/93, training_loss = 0.1050
# epoch 4/4, step 51/93, training_loss = 0.1049
# epoch 4/4, step 52/93, training_loss = 0.1241
# epoch 4/4, step 53/93, training_loss = 0.1068
# epoch 4/4, step 54/93, training_loss = 0.0913
# epoch 4/4, step 55/93, training_loss = 0.1045
# epoch 4/4, step 56/93, training_loss = 0.0914
# epoch 4/4, step 57/93, training_loss = 0.1058
# epoch 4/4, step 58/93, training_loss = 0.1234
# epoch 4/4, step 59/93, training_loss = 0.1011
# epoch 4/4, step 60/93, training_loss = 0.1000
# epoch 4/4, step 61/93, training_loss = 0.1154
# epoch 4/4, step 62/93, training_loss = 0.1285
# epoch 4/4, step 63/93, training_loss = 0.0755
# epoch 4/4, step 64/93, training_loss = 0.0901
# epoch 4/4, step 65/93, training_loss = 0.1293
# epoch 4/4, step 66/93, training_loss = 0.0953
# epoch 4/4, step 67/93, training_loss = 0.1133
# epoch 4/4, step 68/93, training_loss = 0.0881
# epoch 4/4, step 69/93, training_loss = 0.1156
# epoch 4/4, step 70/93, training_loss = 0.1000
# epoch 4/4, step 71/93, training_loss = 0.0882
# epoch 4/4, step 72/93, training_loss = 0.0838
# epoch 4/4, step 73/93, training_loss = 0.1095
# epoch 4/4, step 74/93, training_loss = 0.0959
# epoch 4/4, step 75/93, training_loss = 0.0772
# epoch 4/4, step 76/93, training_loss = 0.0997
# epoch 4/4, step 77/93, training_loss = 0.1080
# epoch 4/4, step 78/93, training_loss = 0.0985
# epoch 4/4, step 79/93, training_loss = 0.0882
# epoch 4/4, step 80/93, training_loss = 0.0870
# epoch 4/4, step 81/93, training_loss = 0.0679
# epoch 4/4, step 82/93, training_loss = 0.0743
# epoch 4/4, step 83/93, training_loss = 0.0898
# epoch 4/4, step 84/93, training_loss = 0.1018
# epoch 4/4, step 85/93, training_loss = 0.0842
# epoch 4/4, step 86/93, training_loss = 0.0761
# epoch 4/4, step 87/93, training_loss = 0.0804
# epoch 4/4, step 88/93, training_loss = 0.0808
# epoch 4/4, step 89/93, training_loss = 0.0827
# epoch 4/4, step 90/93, training_loss = 0.0819
# epoch 4/4, step 91/93, training_loss = 0.0819
# epoch 4/4, step 92/93, training_loss = 0.0950
# epoch 4/4, step 93/93, training_loss = 0.2400
# evaluation for epoch 4, accuracy = 0.9871, rocauc = 0.9998
# train completed, best_metric: 0.9998 at epoch: 3

# %% [markdown]
# We'll also fix up a couple of outstanding issues that the notebook has in its current form.

# %% [markdown]
# #### Issues with determinism
#
# MONAI provides `monai.utils.set_determinism` for replicable training
# - Easy to not think about, especially in a jupyter / IPython notebook
#
# How many uses of `numpy.random`'s underlying global instance does this notebook have?
# - Dataset partitioning
# - Image previewing
# - MONAI transforms with randomised behaviour can be given / told to create their own internal `numpy.random.RandomState` instances

# %% [markdown]
# #### Setting up transforms, revisited

# %%
rseed = 12345678

train_transforms = Compose(
    [
        LoadImage(image_only=True),
        AddChannel(),
        ScaleIntensity(),
        RandRotate(range_x=15, prob=0.5, keep_size=True).set_random_state(rseed),
        RandFlip(spatial_axis=0, prob=0.5).set_random_state(rseed),
        RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.5).set_random_state(rseed),
        ToTensor(),
    ]
)

val_transforms = Compose([LoadImage(image_only=True), AddChannel(), ScaleIntensity(), ToTensor()])

# %% [markdown]
# #### Improving dataset partitioning
#
# - Current code results in random numbers of images / labels each time it is run
# - np.shuffle to the rescue

# %%
from math import floor

# make this selection deterministic and controllable by seed
dataset_seed = 12345678
r = np.random.RandomState(dataset_seed)

# calculate the number of images we want for the validation and test groups
validation_proportion = 0.1
test_proportion = 0.1
validation_count = floor(validation_proportion * num_total)
test_count = floor(test_proportion * num_total)

groups = np.zeros(num_total, dtype=np.int32)

# set the appropriate number of '1's for the validation dataset
groups[:validation_count] = 1

# then set the appropriate number of '2's for the test dataset
groups[validation_count:validation_count + test_count] = 2

# Shuffle the sequence so that 
r.shuffle(groups)

image_sets = list(), list(), list()
label_sets = list(), list(), list()

for n in range(num_total):
    image_sets[groups[n]].append(image_files_list[n])
    label_sets[groups[n]].append(image_class[n])
    
train_x, val_x, test_x = image_sets
train_y, val_y, test_y = label_sets
print(len(train_x), len(val_x), len(test_x))

# %% [markdown]
# ## **Summary**
#
# In this notebook, we went through an end-to-end workflow to train the MedNIST dataset using a densenet121 network.  Along the way, you did the following:
# - Learned about the MedNIST Data and downloaded it
# - Visualized the data to understand the images
# - Setup the datasets for use in the model training
# - Defined our transforms, datasets, network, and optimizers
# - Trained a densenet model and saved the best model as determined by the validation accuracy
# - Plotted your training results
# - Evaluated your model against the test set
# - Ran your final predictions through a classification report to understand more about your final results
# - Created a new workflow using Ignite
# - Learn more about issues with determinism and how to look out for pitfalls

# %% [markdown]
# ## **Next Steps**
#
# In the next notebook, we cover sliding window inference and post-processing transforms.
#
# You can find more information about everything covered here on our [MONAI Documentation Page](https://docs.monai.io/).
#
# If you're looking for more examples and tutorials, we have a repo dedicated just to that!  You can find it on our [GitHub Organization Page](https://github.com/Project-MONAI/tutorials).  We also have all of our videos from our first ever MONAI Bootcamp available on our [Youtube Channel](https://www.youtube.com/c/ProjectMONAI)
